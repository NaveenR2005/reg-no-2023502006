# %% [markdown]
# <a href="https://colab.research.google.com/github/NaveenR2005/reg-no-2023502006/blob/main/Text_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install -q gradio gtts

import gradio as gr
from gtts import gTTS
import tempfile
import os

def text_to_speech(text):
    if not text.strip():
        return None
    # Generate speech audio and save to a temp file
    with tempfile.NamedTemporaryFile(suffix=".mp3", delete=False) as tmp:
        tts = gTTS(text=text, lang='en')
        tts.save(tmp.name)
        tmp_path = tmp.name
    return tmp_path

# Gradio interface with textbox input and audio output
iface = gr.Interface(
    fn=text_to_speech,
    inputs=gr.Textbox(lines=4, placeholder="Enter text to convert to speech..."),
    outputs=gr.Audio(type="filepath"),
    title="Text to Speech Converter",
    description="Enter any text, and hear it spoken aloud!"
)

iface.launch()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 MB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.1/323.1 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 58.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.5 MB/s eta 0:00:00
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://321b7d0703cafa7352.gradio.live
#
# ...

# %%
# Out:
# Enter your prompt for Gemini: Hi i am naveen
#
# Gemini Output:
#  Hi Naveen!  How can I help you today?
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Step 1: Install the gTTS library
# !pip install -q gtts
#
# # Step 2: Import necessary libraries
# from gtts import gTTS
# from IPython.display import Audio
#
# # Step 3: Take user input for the text
# user_input = input("Enter the text you want to convert to speech: ")
#
# # Step 4: Generate speech using gTTS
# tts = gTTS(user_input)
#
# # Step 5: Save the speech to an MP3 file
# tts.save("response.mp3")
#
# # Step 6: Play the generated audio
# display(Audio("response.mp3"))
